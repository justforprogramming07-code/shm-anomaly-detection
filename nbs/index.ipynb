# %%
#| hide
from shm_anomaly_detection.core import *

# %% [markdown]
# # shm-anomaly-detection
#
# > Anomaly detection on KW51 railway bridge dataset using machine learning

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install shm_anomaly_detection in Development mode

# %% [markdown]
# ```sh
# # make sure shm_anomaly_detection package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to shm_anomaly_detection
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/justforprogramming07-code/shm-anomaly-detection.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c justforprogramming07-code shm_anomaly_detection
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install shm_anomaly_detection
# ```
#
#
# [repo]: https://github.com/justforprogramming07-code/shm-anomaly-detection
# [docs]: https://justforprogramming07-code.github.io/shm-anomaly-detection/
# [pypi]: https://pypi.org/project/shm-anomaly-detection/
# [conda]: https://anaconda.org/justforprogramming07-code/shm-anomaly-detection

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/justforprogramming07-code/shm-anomaly-detection
# [docs]: https://justforprogramming07-code.github.io/shm-anomaly-detection/
# [pypi]: https://pypi.org/project/shm-anomaly-detection/
# [conda]: https://anaconda.org/justforprogramming07-code/shm-anomaly-detection

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
